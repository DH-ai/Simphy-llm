# %%
import os, sys
directory_path = "/home/dhruv/Documents/Work/projects/simphy_NL_scripter/simphy-llm"
sys.path.insert(0, directory_path)

from llmsherpa.readers import LayoutPDFReader
from IPython.core.display import  HTML
from IPython.display import display

# %%
# llmsherpa_api_url = "https://readers.llmsherpa.com/api/document/developer/parseDocument?renderFormat=all"
llmsherpa_api_url = "http://172.17.0.2:5001/api/parseDocument?renderFormat=all&useNewIndentParser=true"
# pdf_url = "https://arxiv.org/pdf/1910.13461.pdf" # also allowed is a file path e.g. /home/downloads/xyz.pdf
# pdf_url = "https://www.apache.org/licenses/LICENSE-2.0.txt"
# pdf_url = "https://microsoft.gcs-web.com/static-files/931d7780-ccfc-47e3-97ad-09d87e12b795"
# pdf_url = "https://podcasts.ceu.edu/sites/podcasts.ceu.edu/files/sample.doc"
# pdf_url = "/Users/ambikasukla/projects/data/Kubernetes.docx"
pdf_url = directory_path + "/docs/SimpScriptGPart4Ch4.pdf"
# pdf_url = "/Users/ambikasukla/Downloads/test.pdf"
# pdf_url = "https://github.com/nlmatics/nlm-ingestor"
# pdf_url = "https://raw.githubusercontent.com/nlmatics/llmsherpa/main/README.md"
# pdf_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=pubmed&id=35362092&retmode=xml"
# pdf_url = "https://solutions.weblite.ca/pdfocrx/scansmpl.pdf"
do_ocr = True
if do_ocr:
    llmsherpa_api_url = llmsherpa_api_url + "&applyOcr=yes"
pdf_reader = LayoutPDFReader(llmsherpa_api_url)
doc = pdf_reader.read_pdf(pdf_url)

# %%
# HTML(doc.sections()[0].to_html(include_children=True, recurse=True))
# doc.sections()[1].block_json
# doc.sections()[0].to_text()
# doc.sections()[1].bbox
# llmsherpa.readers.Layout
display(HTML(doc.to_html()))
kp = doc.json

with open("test.json", "w") as f:
    import json
    json.dump(kp, f, indent=4)
# Out:
# <html><h1>CHAPTER      4:</h1><h1>BODIES      &      JOINTS</h1><h2>Accessing      Body      /Joint      in      Script</h2><p>Body      or      joint      already      existing      in      simulation      can      be      accessed      by      calling      getBody()
#
#   and      getJoint()      functions      of      \\\'world\\\'      object.</p><h2>For      exampLe:</h2><p>var      d=World.getBody      (</p><h2>Creating      Body      /      Joints</h2><h3>1.      By      Defining      New      Objects</h3><p>ects</p><p>New      Body      or      joint      can      be      created      by      calling      world.addxxx()      and
#
#   world.addxXXxXJoint      ()      functions.</p><p>The      following      code      creates
#
# a      rectangle      and
#
# a      disc      connected      by
#
# a      spring      of
#
#   force      constant      40      N/m.</p><p>
#
#   var
#
# d
#
# =      World.addDisc(0.5);
#
#   var
#
# r
#
# =      World.addRectangle(1,      1);
#
#   r.setPosition(2,      0);</p><h3>2.      From      Existing      Objects</h3><p>ects</p><p>Clone      of      body      can      be      created      and      added      to      world      by      calling      function
#
#   createCopy      (body)      in      world      object.</p><p>var      d=World.getBody
#
# (      );</p><p>
#
#   Clones      of      body      can      also      be      created      by      calling      copy      ()      from      body      object,
#
#   but      note      that      this      function      creates      copy      of      object      and      returns      it      without
#
#   adding      it      to      world.</p><p>This      returned      copy      can      later      be      added      to      world      by
#
# _      using
#
#   world.addBody      ()      ;</p><p>
#
#   var      d=World.getBody
#
# (      var      dl=d.copy();
#
#   World.addBody      (d1)      ;</p><h2>Changing      Appearance</h2><p>There      exist      few      functions      in      body      object      to      change      body\\\'s      color,      image      and      text.</p><p>
#
#   var      d=World.getBody
#
# (      )?
#
#
#   d.setFillColor      (“white”)      ;</p><p>
#
#   d.setOutlineColor      (new      Color
#
# (      d.setBrush
#
# (      );</p><p>d.setText      (</p><p>j.setColor      (new      Color
#
# (      Setting      Text      on      Body</p><p>
#
#   Body      can      act      like
#
# a      text      display      box      by      setting      its      text      property      using      setText(text)
#
#   method      on      body      object      text      can      be      simple      text      or      may      contain      shortcodes      for
#
#   multiple      styles      defined      by      comma      separated      attribute      value      pairs      inside      square
#
#   brackets.</p><p>e
#
#    Allowed      attributes</p><p>font
#
# =      Name      of      currently      loaded      fonts X
#
#    =
#
#    x
#
#    coordinate      of      text      position      in      body      local      coordinates
#
#   y
#
# =
#
# y      coordinate      of      text      position      in      body      local      coordinates
#
#   color
#
# =      CSS      color      string      like      "red"      or      "rgb(255,0,0)"      etc
#
#   xalign
#
# =      0,
#
# 1      or
#
# 2      for      left,      center      and      right      respectively
#
#   yalign
#
# =      0,
#
# 1      or
#
# 2      for      bottom,      up      and      down      respectively</p><h3>For      exampLe,</h3><p>Following      value      of      text      set      on      rectangular      body      will      result      as      in      screenshot
#
#   below.</p><p>
#
#   Hello      [font="default-large",      color="red"      alignX="left"      alignY="top"      x="-1",y="0.2"]      Mr      Anderson
#
#   [color="blue"      x="0.03"      y="0.1"]      How
#
# r      u?</p><h4>Mr      Anderson</h4><li>0.0
#
# _      How      ru?</li><p>as)      SimPhy      Scripting      Guide      149
#
#   Dynamics
#
#   d.setPosition(0,      0);
#
#   d.setVelocity(0,      0);
#
#   d.applyImpulse      (new      Vector2(0,      3)     .product(d.getMass()));</p><p>
#
#   All      kinematic      properties      like      position,      velocity,      rotation      as      well      as      dynamic
#
#   properties      like      mass,      inertia,      force      and      torque      can      be      accessed      and      set      using
#
#   script.
# for      example      the      following      code      instantly      brings      body      to      origin      and      set      is
#
#   speed      3m/s      in
#
# y      direction      (by      applying      suitable      impulse)</p><h2>Actions</h2><p>
#
#   Each      body      has      an      action      which      is      updated      each      frame      internally.
# Many      types      of
#
#   actions      are      included      with      SimPhy.
# These      can      be      instantiated,      configured,      and
#
#   added      to
#
# a      body.
# When      the      action      is      complete,      it      will      automatically      be      removed
#
#   from      it.</p><p>Actions      are      generally      used      to      perform      some      task
#
# ,      often      over      time,      giving      nice
#
#   effect      using      specific      interpolation.</p><p>
#
#   Actions      are      created      using      methods      of      actions      object,      for      example      following
#
#   code      moves      body      from      position      (0,0)      to      (3,0)      in
#
# 3      seconds      following      "bounce"
#
#   interpolation.</p><p>var
#
# d
#
# =      World.getBody      (</p><p>d.setMass      (0);</p><p>d.setPosition(0,      0);</p><p>var
#
# a
#
# =      Actions.moveTo(3,      0,      4,
#
#   Method      Summary      for      Bodies</p><h2>Method      and      Description</h2><p>applyForce(double      fx,      double      fy)</p><p>applyImpulse(double      jx,      double      jy)
#
#   Applies      Impulse(in      Newton-sec)      on      center      of      body</p><p>
#
#   applyImpulse(double      jx,      double      jy,
#
#   double      px,      double      py)
#
#   Applies      Impulse(in      Newton      sec)      at      specific      point      of
#
#   body</p><p>
#
#   copy      ()
#
#   Returns      the      Copy      of      this      body,      the      copied      body      is
#
#   same      in      look      and      size,      but      is      placed      at      origin      and
#
#   has      speed      zero</p><p>
#
#   copy      (boolean      applyTransform)
#
#   Returns      the      Copy      of      this      body,      the      copied      body      is
#
#   same      in      look      and      size</p><p>getAction      ()
#
#   Returns      action      associated      to      the      body</p><p>
#
#   double
#
#   Returns      angular      velocity      of      the      body      in      radians      per
#
#   second getAngularVelocity      ()
#
#   Modifier      and      Type void void void</p><h2>Body</h2><h2>Body</h2><h2>Action</h2><p>getBrush      ()</p><p>getCharge      ()</p><p>getFillColor      ()
#
#   Returns      the      fill      color.</p><p>
#
#   getHeight      ()
#
#   Returns      width      of      bounding      box      of      non      transformed
#
#   body</p><p>
#
#   getInertia()
#
#   Get      moment      of      inertia      of      body      about      its      center      of
#
#   mass(return
#
# 0      of      body      is      static)</p><p>getMass      ()
#
#   Get      mass      of      body      (return
#
# 0      of      body      is      static)</p><p>getName      ()
#
#   Returns      the      name      of      the      body.</p><p>getOpacity      ()</p><p>getOutlineColor      ()
#
#   Returns      the      outline      color.</p><p>
#
#   getPosition      ()
#
#   Position
